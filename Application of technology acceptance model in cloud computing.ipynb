# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\sharm\Downloads\newwwwwwww'\Python Work\TAM.csv")
df.head()
# Out:
#    year  usefulness  easeofuse  security  behavior  businessprocessoutcome
# 0  2015           1          1         0         0                       0
# 1  2016           1          1         0         0                       0
# 2  2017           1          1         1         1                       1
# 3  2018           0          1         0         0                       1
# 4  2019           0          0         0         0                       1

# %%
sns.lmplot(data=df,x="businessprocessoutcome",y="year")

# %%
sns.lmplot(data=df,x="businessprocessoutcome",y="usefulness")

# %%
sns.lmplot(data=df,x="businessprocessoutcome",y="easeofuse")

# %%
sns.lmplot(data=df,x="businessprocessoutcome",y="security")

# %%
sns.lmplot(data=df,x="businessprocessoutcome",y="behavior")

# %%
x = df.iloc[:,:5]
x
# Out:
#    year  usefulness  easeofuse  security  behavior
# 0  2015           1          1         0         0
# 1  2016           1          1         0         0
# 2  2017           1          1         1         1
# 3  2018           0          1         0         0
# 4  2019           0          0         0         0
# 5  2020           1          1         0         0
# 6  2021           1          1         1         0
# 7  2022           1          1         1         1

# %%
y = df.iloc[:,5]
y
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    1
# 5    1
# 6    1
# 7    1
# Name: businessprocessoutcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(df[['year','usefulness','easeofuse','security','behavior']],df[['businessprocessoutcome']])
# Out:
# LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)
y_pred
# Out:
# array([1. , 0. , 0.2])

# %%
from sklearn.metrics import r2_score
r2_square = r2_score(y_pred,y_test)
print(r2_square)
# Out:
# -0.8571428571428337
